# %%
import pandas as pd

# %% [markdown]
# ---

# %% [markdown]
# GConvLSTM

# %%
pd.concat([pd.read_csv('./simulation_results/2024-01-24_01-17-39.csv'), # 1
           pd.read_csv('./simulation_results/2024-01-24_08-15-26.csv'), # 2
           pd.read_csv('./simulation_results/2024-01-24_14-17-11.csv'), # 3
           pd.read_csv('./simulation_results/2024-01-25_01-05-51.csv'), # 4
           pd.read_csv('./simulation_results/2024-01-25_12-18-29.csv'), # 5
           pd.read_csv('./simulation_results/2024-01-25_23-41-45.csv'), # 6
           pd.read_csv('./simulation_results/2024-01-26_12-37-25.csv'), # 7
           pd.read_csv('./simulation_results/2024-01-26_21-14-21.csv'), # 7
          ]).assign(model='GConvLSTM')
# Out:
#          dataset    method  mrate mtype  lags  nof_filters inter_method  \
# 0  windmillsmall     STGCN    0.5  rand     8           16       linear
# 1  windmillsmall  IT-STGCN    0.5  rand     8           16       linear
# 0  windmillsmall     STGCN    0.5  rand     8           16       linear
# 1  windmillsmall  IT-STGCN    0.5  rand     8           16       linear
# 0  windmillsmall     STGCN    0.5  rand     8           16       linear
# 1  windmillsmall  IT-STGCN    0.5  rand     8           16       linear
# 0  windmillsmall     STGCN    0.5  rand     8           16       linear
# 1  windmillsmall  IT-STGCN    0.5  rand     8           16       linear
# 0  windmillsmall     STGCN    0.5  rand     8           16       linear
# 1  windmillsmall  IT-STGCN    0.5  rand     8           16       linear
# 0  windmillsmall     STGCN    0.5  rand     8           16       linear
# 1  windmillsmall  IT-STGCN    0.5  rand     8           16       linear
# 0  windmillsmall     STGCN    0.5  rand     8           16       linear
# 1  windmillsmall  IT-STGCN    0.5  rand     8           16       linear
#
#    epoch       mse  calculation_time      model
# 0     50  1.283014       3476.057448  GConvLSTM
# 1     50  0.993595      20334.428533  GConvLSTM
# 0     50  1.325239       4152.208847  GConvLSTM
# 1     50  0.998639      20741.676931  GConvLSTM
# 0     50  1.287660       3829.066359  GConvLSTM
# 1     50  0.995080      17702.747430  GConvLSTM
# 0     50  1.318456       4377.204319  GConvLSTM
# 1     50  0.992620      34329.467202  GConvLSTM
# 0     50  1.357958       6785.776819  GConvLSTM
# 1     50  0.995017      33324.177177  GConvLSTM
# 0     50  1.336195       7186.022908  GConvLSTM
# 1     50  0.991417      33596.694606  GConvLSTM
# 0     50  1.313900       8261.675340  GConvLSTM
# 1     50  0.993833      37881.343013  GConvLSTM

# %% [markdown]
# DyGrEncoder

# %%
pd.concat([pd.read_csv('./simulation_results/2024-01-24_23-09-51.csv'), # 1
           pd.read_csv('./simulation_results/2024-01-25_07-49-42.csv'), # 2
           pd.read_csv('./simulation_results/2024-01-26_01-37-53.csv'), # 3
           pd.read_csv('./simulation_results/2024-01-26_12-20-37.csv'), # 4
           pd.read_csv('./simulation_results/2024-01-26_20-56-38.csv'), # 5
           pd.read_csv('./simulation_results/2024-01-27_05-43-47.csv'), # 6
          ]).assign(model='DyGrEncoder')
# Out:
#                     dataset    method  mrate mtype  lags  nof_filters  \
# 0  windmillsmallDyGrEncoder     STGCN    0.5  rand     8           12
# 1  windmillsmallDyGrEncoder  IT-STGCN    0.5  rand     8           12
# 0  windmillsmallDyGrEncoder     STGCN    0.5  rand     8           12
# 1  windmillsmallDyGrEncoder  IT-STGCN    0.5  rand     8           12
# 0  windmillsmallDyGrEncoder     STGCN    0.5  rand     8           12
# 1  windmillsmallDyGrEncoder  IT-STGCN    0.5  rand     8           12
# 0  windmillsmallDyGrEncoder     STGCN    0.5  rand     8           12
# 1  windmillsmallDyGrEncoder  IT-STGCN    0.5  rand     8           12
# 0  windmillsmallDyGrEncoder     STGCN    0.5  rand     8           12
# 1  windmillsmallDyGrEncoder  IT-STGCN    0.5  rand     8           12
# 0  windmillsmallDyGrEncoder     STGCN    0.5  rand     8           12
# 1  windmillsmallDyGrEncoder  IT-STGCN    0.5  rand     8           12
#
#   inter_method  epoch       mse  calculation_time        model
# 0       linear     50  1.399403       1287.129029  DyGrEncoder
# 1       linear     50  0.995185      29379.109457  DyGrEncoder
# 0       linear     50  1.364160       2173.189621  DyGrEncoder
# 1       linear     50  0.990419      28916.702413  DyGrEncoder
# 0       linear     50  1.389555       2051.929635  DyGrEncoder
# 1       linear     50  0.995240      29975.615015  DyGrEncoder
# 0       linear     50  1.357190       2952.702301  DyGrEncoder
# 1       linear     50  0.990371      35552.520746  DyGrEncoder
# 0       linear     50  1.357729       1792.262343  DyGrEncoder
# 1       linear     50  0.995582      29117.568311  DyGrEncoder
# 0       linear     50  1.359898       2105.582545  DyGrEncoder
# 1       linear     50  0.995981      29467.090409  DyGrEncoder

# %% [markdown]
# LRGCN

# %%
pd.concat([pd.read_csv('./simulation_results/2024-01-25_00-26-15.csv'), # 1
           pd.read_csv('./simulation_results/2024-01-25_10-04-35.csv'), # 2
           pd.read_csv('./simulation_results/2024-01-25_19-42-50.csv'), # 3
           pd.read_csv('./simulation_results/2024-01-26_06-17-49.csv'), # 4
           pd.read_csv('./simulation_results/2024-01-26_16-19-15.csv'), # 5
           pd.read_csv('./simulation_results/2024-01-27_01-56-42.csv'), # 6
          ]).assign(model='LRGCN')
# Out:
#               dataset    method  mrate mtype  lags  nof_filters inter_method  \
# 0  windmillsmallLRGCN     STGCN    0.5  rand     8           12       linear
# 1  windmillsmallLRGCN  IT-STGCN    0.5  rand     8           12       linear
# 0  windmillsmallLRGCN     STGCN    0.5  rand     8           12       linear
# 1  windmillsmallLRGCN  IT-STGCN    0.5  rand     8           12       linear
# 0  windmillsmallLRGCN     STGCN    0.5  rand     8           12       linear
# 1  windmillsmallLRGCN  IT-STGCN    0.5  rand     8           12       linear
# 0  windmillsmallLRGCN     STGCN    0.5  rand     8           12       linear
# 1  windmillsmallLRGCN  IT-STGCN    0.5  rand     8           12       linear
# 0  windmillsmallLRGCN     STGCN    0.5  rand     8           12       linear
# 1  windmillsmallLRGCN  IT-STGCN    0.5  rand     8           12       linear
# 0  windmillsmallLRGCN     STGCN    0.5  rand     8           12       linear
# 1  windmillsmallLRGCN  IT-STGCN    0.5  rand     8           12       linear
#
#    epoch       mse  calculation_time  model
# 0     50  1.419365       2706.468822  LRGCN
# 1     50  0.992892      32066.538508  LRGCN
# 0     50  1.353130       3044.404266  LRGCN
# 1     50  0.992260      31543.776187  LRGCN
# 0     50  1.334008       3188.164355  LRGCN
# 1     50  0.995353      31375.653413  LRGCN
# 0     50  1.337325       3132.741006  LRGCN
# 1     50  0.992040      34839.083089  LRGCN
# 0     50  1.371451       3077.019833  LRGCN
# 1     50  0.993275      32914.471802  LRGCN
# 0     50  1.312752       2960.035801  LRGCN
# 1     50  0.991522      31567.534146  LRGCN

# %% [markdown]
# ---

# %% [markdown]
# pedalme

# %%
# pd.concat([pd.read_csv('./simulation_results/pedalme_linear_old.csv'),
#           pd.read_csv('./simulation_results/2024-01-25_17-58-42.csv').assign(model='LRGCN').iloc[:,1:].assign(dataset='pedalme'),
#            pd.read_csv('./simulation_results/pedalme_linear_block_old.csv'),
#           pd.read_csv('./simulation_results/2024-01-25_18-06-45.csv').assign(model='LRGCN').iloc[:,1:].assign(dataset='pedalme')]).iloc[:,1:].to_csv('pedalme_linear.csv',index=False)

# %% [markdown]
# ---

# %% [markdown]
# monte

# %% [markdown]
# block

# %%
pd.concat([pd.read_csv('./simulation_results/2024-01-26_05-21-17.csv').assign(model='GComvGRU'), # 15(1)
           pd.read_csv('./simulation_results/2024-01-26_09-48-48.csv').assign(model='GComvGRU'), # 15(2)
          ])
# Out:
#                dataset    method     mrate  mtype  lags  nof_filters  \
# 0   monteblockGConvGRU     STGCN  0.149142  block     4           12
# 1   monteblockGConvGRU  IT-STGCN  0.149142  block     4           12
# 2   monteblockGConvGRU     STGCN  0.149142  block     4           12
# 3   monteblockGConvGRU  IT-STGCN  0.149142  block     4           12
# 4   monteblockGConvGRU     STGCN  0.149142  block     4           12
# 5   monteblockGConvGRU  IT-STGCN  0.149142  block     4           12
# 6   monteblockGConvGRU     STGCN  0.149142  block     4           12
# 7   monteblockGConvGRU  IT-STGCN  0.149142  block     4           12
# 8   monteblockGConvGRU     STGCN  0.149142  block     4           12
# 9   monteblockGConvGRU  IT-STGCN  0.149142  block     4           12
# 10  monteblockGConvGRU     STGCN  0.149142  block     4           12
# 11  monteblockGConvGRU  IT-STGCN  0.149142  block     4           12
# 12  monteblockGConvGRU     STGCN  0.149142  block     4           12
# 13  monteblockGConvGRU  IT-STGCN  0.149142  block     4           12
# 14  monteblockGConvGRU     STGCN  0.149142  block     4           12
# 15  monteblockGConvGRU  IT-STGCN  0.149142  block     4           12
# 16  monteblockGConvGRU     STGCN  0.149142  block     4           12
# 17  monteblockGConvGRU  IT-STGCN  0.149142  block     4           12
# 18  monteblockGConvGRU     STGCN  0.149142  block     4           12
# 19  monteblockGConvGRU  IT-STGCN  0.149142  block     4           12
# 20  monteblockGConvGRU     STGCN  0.149142  block     4           12
# 21  monteblockGConvGRU  IT-STGCN  0.149142  block     4           12
# 22  monteblockGConvGRU     STGCN  0.149142  block     4           12
# 23  monteblockGConvGRU  IT-STGCN  0.149142  block     4           12
# 24  monteblockGConvGRU     STGCN  0.149142  block     4           12
# 25  monteblockGConvGRU  IT-STGCN  0.149142  block     4           12
# 26  monteblockGConvGRU     STGCN  0.149142  block     4           12
# 27  monteblockGConvGRU  IT-STGCN  0.149142  block     4           12
# 28  monteblockGConvGRU     STGCN  0.149142  block     4           12
# 29  monteblockGConvGRU  IT-STGCN  0.149142  block     4           12
# 0   monteblockGConvGRU     STGCN  0.149142  block     4           12
# 1   monteblockGConvGRU  IT-STGCN  0.149142  block     4           12
# 2   monteblockGConvGRU     STGCN  0.149142  block     4           12
# 3   monteblockGConvGRU  IT-STGCN  0.149142  block     4           12
# 4   monteblockGConvGRU     STGCN  0.149142  block     4           12
# 5   monteblockGConvGRU  IT-STGCN  0.149142  block     4           12
# 6   monteblockGConvGRU     STGCN  0.149142  block     4           12
# 7   monteblockGConvGRU  IT-STGCN  0.149142  block     4           12
# 8   monteblockGConvGRU     STGCN  0.149142  block     4           12
# 9   monteblockGConvGRU  IT-STGCN  0.149142  block     4           12
# 10  monteblockGConvGRU     STGCN  0.149142  block     4           12
# 11  monteblockGConvGRU  IT-STGCN  0.149142  block     4           12
# 12  monteblockGConvGRU     STGCN  0.149142  block     4           12
# 13  monteblockGConvGRU  IT-STGCN  0.149142  block     4           12
# 14  monteblockGConvGRU     STGCN  0.149142  block     4           12
# 15  monteblockGConvGRU  IT-STGCN  0.149142  block     4           12
# 16  monteblockGConvGRU     STGCN  0.149142  block     4           12
# 17  monteblockGConvGRU  IT-STGCN  0.149142  block     4           12
# 18  monteblockGConvGRU     STGCN  0.149142  block     4           12
# 19  monteblockGConvGRU  IT-STGCN  0.149142  block     4           12
# 20  monteblockGConvGRU     STGCN  0.149142  block     4           12
# 21  monteblockGConvGRU  IT-STGCN  0.149142  block     4           12
# 22  monteblockGConvGRU     STGCN  0.149142  block     4           12
# 23  monteblockGConvGRU  IT-STGCN  0.149142  block     4           12
# 24  monteblockGConvGRU     STGCN  0.149142  block     4           12
# 25  monteblockGConvGRU  IT-STGCN  0.149142  block     4           12
# 26  monteblockGConvGRU     STGCN  0.149142  block     4           12
# 27  monteblockGConvGRU  IT-STGCN  0.149142  block     4           12
# 28  monteblockGConvGRU     STGCN  0.149142  block     4           12
# 29  monteblockGConvGRU  IT-STGCN  0.149142  block     4           12
#
#    inter_method  epoch       mse  calculation_time     model
# 0        linear     50  0.931718        299.104043  GComvGRU
# 1        linear     50  0.931139        550.015985  GComvGRU
# 2        linear     50  0.930514        570.290766  GComvGRU
# 3        linear     50  0.933784        610.768229  GComvGRU
# 4        linear     50  0.931011        265.058070  GComvGRU
# 5        linear     50  0.929757        674.040715  GComvGRU
# 6        linear     50  0.932275        425.857081  GComvGRU
# 7        linear     50  0.930852        562.374390  GComvGRU
# 8        linear     50  0.934731        411.990982  GComvGRU
# 9        linear     50  0.936990        664.307830  GComvGRU
# 10       linear     50  0.930695        395.249585  GComvGRU
# 11       linear     50  0.931442        521.525001  GComvGRU
# 12       linear     50  0.932494        610.015810  GComvGRU
# 13       linear     50  0.932101        670.815484  GComvGRU
# 14       linear     50  0.929891        340.687619  GComvGRU
# 15       linear     50  0.930814        688.510900  GComvGRU
# 16       linear     50  0.929568        530.603474  GComvGRU
# 17       linear     50  0.934458        627.509763  GComvGRU
# 18       linear     50  0.931746        549.576937  GComvGRU
# 19       linear     50  0.930138        582.252268  GComvGRU
# 20       linear     50  0.933423        399.936904  GComvGRU
# 21       linear     50  0.929868        715.416811  GComvGRU
# 22       linear     50  0.930802        409.318287  GComvGRU
# 23       linear     50  0.931395        544.664550  GComvGRU
# 24       linear     50  0.931638        583.273260  GComvGRU
# 25       linear     50  0.931750        667.601656  GComvGRU
# 26       linear     50  0.942542        281.407660  GComvGRU
# 27       linear     50  0.932974        645.180369  GComvGRU
# 28       linear     50  0.930067        612.553957  GComvGRU
# 29       linear     50  0.932761        558.296924  GComvGRU
# 0        linear     50  0.932488        372.226394  GComvGRU
# 1        linear     50  0.930379        699.658128  GComvGRU
# 2        linear     50  0.931438        415.605205  GComvGRU
# 3        linear     50  0.930347        542.798099  GComvGRU
# 4        linear     50  0.930008        562.986979  GComvGRU
# 5        linear     50  0.928100        659.513895  GComvGRU
# 6        linear     50  0.931606        247.083671  GComvGRU
# 7        linear     50  0.931921        561.147928  GComvGRU
# 8        linear     50  0.936320        408.399451  GComvGRU
# 9        linear     50  0.931158        499.680166  GComvGRU
# 10       linear     50  0.932733        382.932732  GComvGRU
# 11       linear     50  0.931796        501.847627  GComvGRU
# 12       linear     50  0.930121        398.458052  GComvGRU
# 13       linear     50  0.934384        577.732913  GComvGRU
# 14       linear     50  0.938307        332.404821  GComvGRU
# 15       linear     50  0.928826        712.387104  GComvGRU
# 16       linear     50  0.933157        535.517251  GComvGRU
# 17       linear     50  0.931454        541.591015  GComvGRU
# 18       linear     50  0.934156        467.824079  GComvGRU
# 19       linear     50  0.932229        695.850091  GComvGRU
# 20       linear     50  0.933623        349.885399  GComvGRU
# 21       linear     50  0.934271        595.696776  GComvGRU
# 22       linear     50  0.932913        610.674303  GComvGRU
# 23       linear     50  0.930285        668.320416  GComvGRU
# 24       linear     50  0.927861        345.334535  GComvGRU
# 25       linear     50  0.927856        666.427625  GComvGRU
# 26       linear     50  0.937333        551.077905  GComvGRU
# 27       linear     50  0.929876        638.035704  GComvGRU
# 28       linear     50  0.930511        552.010496  GComvGRU
# 29       linear     50  0.932798        624.164069  GComvGRU
