# %% [raw]
# ---
# title: "시뮬 데이터 정리중"
# author: "SEOYEON CHOI"
# date: "2024-01-28"
# ---

# %% [markdown]
# | Model               | FiveVTS | Chickenpox | Pedalme | Wikimath | Windmillsmall | MontevideoBus |
# |---------------------|---------|------------|---------|----------|---------------|---------------|
# | Max iter.           | 30      | 30         | 30      | 30       | 30            | 30            |
# | Epochs              | 50      | 50         | 50      | 50       | 50            | 50            |
# | Lags                | 2       | 4          | 4       | 8        | 8             | 4             |
# | Interpolation       | linear  | linear     | nearest | linear   | linear        | nearest       |
# | Filters             |         |            |         |          |               |               |
# | GConvGRU            | 12      | 16         | 12      | 12       | 12            | 12            |
# | GConvLSTM           | 12      | 32         | 2       | 64       | 16            | 12            |
# | GCLSTM              | 4       | 16         | 4       | 64       | 16            | 12            |
# | LRGCN               | 4       | 8          | 8       | 32       | 12            | 2             |
# | DyGrEncoder         | 12      | 12         | 12      | 12       | 12            | 12            |
# | EvolveGCNH          | No need | No need    | No need | No need  | No need       | No need       |
# | EvolveGCNO          | No need | No need    | No need | No need  | No need       | No need       |
# | TGCN                | 12      | 12         | 12      | 12       | 12            | 8             |
# | DCRNN               | 2       | 16         | 8       | 12       | 4             | 12            |

# %% [markdown]
# GConvLSTM

# %%
pd.concat([pd.read_csv('./simulation_results/2024-01-24_01-17-39.csv'), # 1
           pd.read_csv('./simulation_results/2024-01-24_08-15-26.csv'), # 2
           pd.read_csv('./simulation_results/2024-01-24_14-17-11.csv'), # 3
           pd.read_csv('./simulation_results/2024-01-25_01-05-51.csv'), # 4
           pd.read_csv('./simulation_results/2024-01-25_12-18-29.csv'), # 5
           pd.read_csv('./simulation_results/2024-01-25_23-41-45.csv'), # 6
           pd.read_csv('./simulation_results/2024-01-26_12-37-25.csv'), # 7
           pd.read_csv('./simulation_results/2024-01-26_21-14-21.csv'), # 8
           pd.read_csv('./simulation_results/2024-01-27_08-50-46.csv'), # 9
           pd.read_csv('./simulation_results/2024-01-27_19-02-29.csv'), # 10
           pd.read_csv('./simulation_results/2024-01-28_08-29-10.csv'), # 11
           pd.read_csv('./simulation_results/2024-01-28_17-22-21.csv'), # 12
           pd.read_csv('./simulation_results/2024-01-29_05-59-51.csv'), # 13
           pd.read_csv('./simulation_results/2024-01-29_15-49-49.csv'), # 14
           pd.read_csv('./simulation_results/2024-01-30_04-23-51.csv'), # 15
           pd.read_csv('./simulation_results/2024-01-30_23-11-56.csv'), # 16
           pd.read_csv('./simulation_results/2024-01-31_14-01-41.csv'), # 17
           pd.read_csv('./simulation_results/2024-02-01_04-15-58.csv'), # 18
           pd.read_csv('./simulation_results/2024-02-01_19-29-23.csv'), # 19
           pd.read_csv('./simulation_results/2024-02-02_09-52-22.csv'), # 20
           pd.read_csv('./simulation_results/2024-02-03_00-11-56.csv'), # 21
           pd.read_csv('./simulation_results/2024-02-03_14-38-41.csv'), # 22
           pd.read_csv('./simulation_results/2024-02-04_05-42-18.csv'), # 23
           pd.read_csv('./simulation_results/2024-02-04_20-15-56.csv'), # 24
           pd.read_csv('./simulation_results/2024-02-05_10-59-26.csv'), # 25
           pd.read_csv('./simulation_results/2024-02-06_02-03-46.csv'), # 26
           pd.read_csv('./simulation_results/2024-02-06_16-24-31.csv'), # 27
           pd.read_csv('./simulation_results/2024-02-07_04-29-11.csv'), # 28
           pd.read_csv('./simulation_results/2024-02-07_15-48-58.csv'), # 29
           pd.read_csv('./simulation_results/2024-02-08_02-55-19.csv'), # 30
          ]).assign(model='GConvLSTM').iloc[:,1:].assign(dataset='windmillsmall').to_csv()
# Out:
#      method  mrate mtype  lags  nof_filters inter_method  epoch       mse  \
# 0     STGCN    0.5  rand     8           16       linear     50  1.283014
# 1  IT-STGCN    0.5  rand     8           16       linear     50  0.993595
# 0     STGCN    0.5  rand     8           16       linear     50  1.325239
# 1  IT-STGCN    0.5  rand     8           16       linear     50  0.998639
# 0     STGCN    0.5  rand     8           16       linear     50  1.287660
# 1  IT-STGCN    0.5  rand     8           16       linear     50  0.995080
# 0     STGCN    0.5  rand     8           16       linear     50  1.318456
# 1  IT-STGCN    0.5  rand     8           16       linear     50  0.992620
# 0     STGCN    0.5  rand     8           16       linear     50  1.357958
# 1  IT-STGCN    0.5  rand     8           16       linear     50  0.995017
# 0     STGCN    0.5  rand     8           16       linear     50  1.336195
# 1  IT-STGCN    0.5  rand     8           16       linear     50  0.991417
# 0     STGCN    0.5  rand     8           16       linear     50  1.313900
# 1  IT-STGCN    0.5  rand     8           16       linear     50  0.993833
# 0     STGCN    0.5  rand     8           16       linear     50  1.392125
# 1  IT-STGCN    0.5  rand     8           16       linear     50  0.997460
# 0     STGCN    0.5  rand     8           16       linear     50  1.318593
# 1  IT-STGCN    0.5  rand     8           16       linear     50  0.998245
# 0     STGCN    0.5  rand     8           16       linear     50  1.399153
# 1  IT-STGCN    0.5  rand     8           16       linear     50  0.996699
# 0     STGCN    0.5  rand     8           16       linear     50  1.309674
# 1  IT-STGCN    0.5  rand     8           16       linear     50  0.996202
# 0     STGCN    0.5  rand     8           16       linear     50  1.301730
# 1  IT-STGCN    0.5  rand     8           16       linear     50  0.997166
# 0     STGCN    0.5  rand     8           16       linear     50  1.370083
# 1  IT-STGCN    0.5  rand     8           16       linear     50  0.995826
# 0     STGCN    0.5  rand     8           16       linear     50  1.372389
# 1  IT-STGCN    0.5  rand     8           16       linear     50  1.001526
# 0     STGCN    0.5  rand     8           16       linear     50  1.274451
# 1  IT-STGCN    0.5  rand     8           16       linear     50  1.001688
# 0     STGCN    0.5  rand     8           16       linear     50  1.346107
# 1  IT-STGCN    0.5  rand     8           16       linear     50  0.994169
# 0     STGCN    0.5  rand     8           16       linear     50  1.325019
# 1  IT-STGCN    0.5  rand     8           16       linear     50  0.996566
# 0     STGCN    0.5  rand     8           16       linear     50  1.309472
# 1  IT-STGCN    0.5  rand     8           16       linear     50  0.997760
# 0     STGCN    0.5  rand     8           16       linear     50  1.321779
# 1  IT-STGCN    0.5  rand     8           16       linear     50  0.995853
# 0     STGCN    0.5  rand     8           16       linear     50  1.321575
# 1  IT-STGCN    0.5  rand     8           16       linear     50  0.995497
# 0     STGCN    0.5  rand     8           16       linear     50  1.319878
# 1  IT-STGCN    0.5  rand     8           16       linear     50  0.991498
# 0     STGCN    0.5  rand     8           16       linear     50  1.350290
# 1  IT-STGCN    0.5  rand     8           16       linear     50  0.994273
# 0     STGCN    0.5  rand     8           16       linear     50  1.320736
# 1  IT-STGCN    0.5  rand     8           16       linear     50  1.001478
# 0     STGCN    0.5  rand     8           16       linear     50  1.326591
# 1  IT-STGCN    0.5  rand     8           16       linear     50  1.001975
# 0     STGCN    0.5  rand     8           16       linear     50  1.351121
# 1  IT-STGCN    0.5  rand     8           16       linear     50  0.995536
# 0     STGCN    0.5  rand     8           16       linear     50  1.343666
# 1  IT-STGCN    0.5  rand     8           16       linear     50  0.998899
# 0     STGCN    0.5  rand     8           16       linear     50  1.335792
# 1  IT-STGCN    0.5  rand     8           16       linear     50  0.993743
# 0     STGCN    0.5  rand     8           16       linear     50  1.311089
# 1  IT-STGCN    0.5  rand     8           16       linear     50  1.001709
# 0     STGCN    0.5  rand     8           16       linear     50  1.321473
# 1  IT-STGCN    0.5  rand     8           16       linear     50  0.998108
# 0     STGCN    0.5  rand     8           16       linear     50  1.347701
# 1  IT-STGCN    0.5  rand     8           16       linear     50  0.994034
#
#    calculation_time      model        dataset
# 0       3476.057448  GConvLSTM  windmillsmall
# 1      20334.428533  GConvLSTM  windmillsmall
# 0       4152.208847  GConvLSTM  windmillsmall
# 1      20741.676931  GConvLSTM  windmillsmall
# 0       3829.066359  GConvLSTM  windmillsmall
# 1      17702.747430  GConvLSTM  windmillsmall
# 0       4377.204319  GConvLSTM  windmillsmall
# 1      34329.467202  GConvLSTM  windmillsmall
# 0       6785.776819  GConvLSTM  windmillsmall
# 1      33324.177177  GConvLSTM  windmillsmall
# 0       7186.022908  GConvLSTM  windmillsmall
# 1      33596.694606  GConvLSTM  windmillsmall
# 0       8261.675340  GConvLSTM  windmillsmall
# 1      37881.343013  GConvLSTM  windmillsmall
# 0       1975.735434  GConvLSTM  windmillsmall
# 1      28946.978392  GConvLSTM  windmillsmall
# 0       6948.836621  GConvLSTM  windmillsmall
# 1      34599.245432  GConvLSTM  windmillsmall
# 0       1957.639161  GConvLSTM  windmillsmall
# 1      34667.262108  GConvLSTM  windmillsmall
# 0       9025.758318  GConvLSTM  windmillsmall
# 1      38963.648819  GConvLSTM  windmillsmall
# 0       1961.896874  GConvLSTM  windmillsmall
# 1      29929.752295  GConvLSTM  windmillsmall
# 0       7220.183307  GConvLSTM  windmillsmall
# 1      37932.601738  GConvLSTM  windmillsmall
# 0       2022.779457  GConvLSTM  windmillsmall
# 1      33308.158144  GConvLSTM  windmillsmall
# 0       8294.857512  GConvLSTM  windmillsmall
# 1      36584.506492  GConvLSTM  windmillsmall
# 0       8469.584140  GConvLSTM  windmillsmall
# 1      42063.467053  GConvLSTM  windmillsmall
# 0      10151.427676  GConvLSTM  windmillsmall
# 1      42665.312936  GConvLSTM  windmillsmall
# 0      10100.940994  GConvLSTM  windmillsmall
# 1      40664.061727  GConvLSTM  windmillsmall
# 0      10244.232447  GConvLSTM  windmillsmall
# 1      44122.405391  GConvLSTM  windmillsmall
# 0       9440.919729  GConvLSTM  windmillsmall
# 1      41745.582955  GConvLSTM  windmillsmall
# 0      10666.271813  GConvLSTM  windmillsmall
# 1      40318.143260  GConvLSTM  windmillsmall
# 0       9534.288179  GConvLSTM  windmillsmall
# 1      42068.986470  GConvLSTM  windmillsmall
# 0      10304.426891  GConvLSTM  windmillsmall
# 1      43402.663355  GConvLSTM  windmillsmall
# 0      10396.922740  GConvLSTM  windmillsmall
# 1      41763.624608  GConvLSTM  windmillsmall
# 0      10177.446928  GConvLSTM  windmillsmall
# 1      42641.803051  GConvLSTM  windmillsmall
# 0      10954.173078  GConvLSTM  windmillsmall
# 1      43040.181640  GConvLSTM  windmillsmall
# 0       9605.159828  GConvLSTM  windmillsmall
# 1      41641.768421  GConvLSTM  windmillsmall
# 0      10270.184540  GConvLSTM  windmillsmall
# 1      32864.900430  GConvLSTM  windmillsmall
# 0       7070.096668  GConvLSTM  windmillsmall
# 1      33195.005899  GConvLSTM  windmillsmall
# 0       6902.333389  GConvLSTM  windmillsmall
# 1      32682.190153  GConvLSTM  windmillsmall

# %% [markdown]
# GCLSTM

# %%
pd.concat([pd.read_csv('./simulation_results/2024-01-30_19-56-08.csv'), # 1
           pd.read_csv('./simulation_results/2024-01-31_06-41-15.csv'), # 2
           pd.read_csv('./simulation_results/2024-01-31_17-33-23.csv'), # 3
           pd.read_csv('./simulation_results/2024-02-01_15-53-59.csv'), # 4
           pd.read_csv('./simulation_results/2024-02-02_02-39-21.csv'), # 5
           pd.read_csv('./simulation_results/2024-02-02_13-50-54.csv'), # 6
           pd.read_csv('./simulation_results/2024-02-03_01-08-09.csv'), # 7
           pd.read_csv('./simulation_results/2024-02-03_11-55-58.csv'), # 8
           pd.read_csv('./simulation_results/2024-02-03_22-53-58.csv'), # 9
           pd.read_csv('./simulation_results/2024-02-04_09-45-33.csv'), # 10
           pd.read_csv('./simulation_results/2024-02-05_07-29-54.csv'), # 11
           pd.read_csv('./simulation_results/2024-02-05_18-27-43.csv'), # 12
           pd.read_csv('./simulation_results/2024-02-06_05-10-19.csv'), # 13
           pd.read_csv('./simulation_results/2024-02-06_16-09-48.csv'), # 14
           pd.read_csv('./simulation_results/2024-02-07_01-44-15.csv'), # 15
           pd.read_csv('./simulation_results/2024-02-07_10-31-09.csv'), # 16
           pd.read_csv('./simulation_results/2024-02-07_19-20-00.csv'), # 17
           pd.read_csv('./simulation_results/2024-02-08_04-03-03.csv'), # 18
          ]).assign(model='GCLSTM')
# Out:
#                dataset    method  mrate mtype  lags  nof_filters inter_method  \
# 0  windmillsmallGCLSTM     STGCN    0.5  rand     8           16       linear
# 1  windmillsmallGCLSTM  IT-STGCN    0.5  rand     8           16       linear
# 0  windmillsmallGCLSTM     STGCN    0.5  rand     8           16       linear
# 1  windmillsmallGCLSTM  IT-STGCN    0.5  rand     8           16       linear
# 0  windmillsmallGCLSTM     STGCN    0.5  rand     8           16       linear
# 1  windmillsmallGCLSTM  IT-STGCN    0.5  rand     8           16       linear
# 0  windmillsmallGCLSTM     STGCN    0.5  rand     8           16       linear
# 1  windmillsmallGCLSTM  IT-STGCN    0.5  rand     8           16       linear
# 0  windmillsmallGCLSTM     STGCN    0.5  rand     8           16       linear
# 1  windmillsmallGCLSTM  IT-STGCN    0.5  rand     8           16       linear
# 0  windmillsmallGCLSTM     STGCN    0.5  rand     8           16       linear
# 1  windmillsmallGCLSTM  IT-STGCN    0.5  rand     8           16       linear
# 0  windmillsmallGCLSTM     STGCN    0.5  rand     8           16       linear
# 1  windmillsmallGCLSTM  IT-STGCN    0.5  rand     8           16       linear
# 0  windmillsmallGCLSTM     STGCN    0.5  rand     8           16       linear
# 1  windmillsmallGCLSTM  IT-STGCN    0.5  rand     8           16       linear
# 0  windmillsmallGCLSTM     STGCN    0.5  rand     8           16       linear
# 1  windmillsmallGCLSTM  IT-STGCN    0.5  rand     8           16       linear
# 0  windmillsmallGCLSTM     STGCN    0.5  rand     8           16       linear
# 1  windmillsmallGCLSTM  IT-STGCN    0.5  rand     8           16       linear
# 0  windmillsmallGCLSTM     STGCN    0.5  rand     8           16       linear
# 1  windmillsmallGCLSTM  IT-STGCN    0.5  rand     8           16       linear
# 0  windmillsmallGCLSTM     STGCN    0.5  rand     8           16       linear
# 1  windmillsmallGCLSTM  IT-STGCN    0.5  rand     8           16       linear
# 0  windmillsmallGCLSTM     STGCN    0.5  rand     8           16       linear
# 1  windmillsmallGCLSTM  IT-STGCN    0.5  rand     8           16       linear
# 0  windmillsmallGCLSTM     STGCN    0.5  rand     8           16       linear
# 1  windmillsmallGCLSTM  IT-STGCN    0.5  rand     8           16       linear
# 0  windmillsmallGCLSTM     STGCN    0.5  rand     8           16       linear
# 1  windmillsmallGCLSTM  IT-STGCN    0.5  rand     8           16       linear
# 0  windmillsmallGCLSTM     STGCN    0.5  rand     8           16       linear
# 1  windmillsmallGCLSTM  IT-STGCN    0.5  rand     8           16       linear
# 0  windmillsmallGCLSTM     STGCN    0.5  rand     8           16       linear
# 1  windmillsmallGCLSTM  IT-STGCN    0.5  rand     8           16       linear
# 0  windmillsmallGCLSTM     STGCN    0.5  rand     8           16       linear
# 1  windmillsmallGCLSTM  IT-STGCN    0.5  rand     8           16       linear
#
#    epoch       mse  calculation_time   model
# 0     50  1.330430       1792.330074  GCLSTM
# 1     50  0.994657      37549.984292  GCLSTM
# 0     50  1.359908       2055.306092  GCLSTM
# 1     50  0.998234      36563.113898  GCLSTM
# 0     50  1.321563       2070.829286  GCLSTM
# 1     50  0.996151      36958.077909  GCLSTM
# 0     50  1.379681       1906.408530  GCLSTM
# 1     50  0.996564      38225.822906  GCLSTM
# 0     50  1.356987       2111.475431  GCLSTM
# 1     50  0.995430      36512.732165  GCLSTM
# 0     50  1.310014       2160.309125  GCLSTM
# 1     50  0.995564      38037.115601  GCLSTM
# 0     50  1.294767       2062.107037  GCLSTM
# 1     50  0.996634      38485.502652  GCLSTM
# 0     50  1.357890       1910.629814  GCLSTM
# 1     50  0.993967      36870.318247  GCLSTM
# 0     50  1.297209       2042.895210  GCLSTM
# 1     50  0.994180      37344.073838  GCLSTM
# 0     50  1.301492       2158.601241  GCLSTM
# 1     50  0.993494      36841.169263  GCLSTM
# 0     50  1.303688       1969.234654  GCLSTM
# 1     50  1.002213      36974.702256  GCLSTM
# 0     50  1.345670       2088.566485  GCLSTM
# 1     50  0.996891      37316.866795  GCLSTM
# 0     50  1.378040       2079.124532  GCLSTM
# 1     50  0.998819      36383.323611  GCLSTM
# 0     50  1.332490       2148.813818  GCLSTM
# 1     50  0.991536      37344.369913  GCLSTM
# 0     50  1.318560       2060.434979  GCLSTM
# 1     50  0.993846      32299.529831  GCLSTM
# 0     50  1.365433       1797.842300  GCLSTM
# 1     50  0.991101      29730.212215  GCLSTM
# 0     50  1.391681       1931.081334  GCLSTM
# 1     50  0.999259      29718.411346  GCLSTM
# 0     50  1.267165       1908.632221  GCLSTM
# 1     50  0.997551      29370.309767  GCLSTM

# %% [markdown]
# DyGrEncoder

# %%
pd.concat([pd.read_csv('./simulation_results/2024-01-24_23-09-51.csv'), # 1
           pd.read_csv('./simulation_results/2024-01-25_07-49-42.csv'), # 2
           pd.read_csv('./simulation_results/2024-01-26_01-37-53.csv'), # 3
           pd.read_csv('./simulation_results/2024-01-26_12-20-37.csv'), # 4
           pd.read_csv('./simulation_results/2024-01-26_20-56-38.csv'), # 5
           pd.read_csv('./simulation_results/2024-01-27_05-43-47.csv'), # 6
           pd.read_csv('./simulation_results/2024-01-27_16-32-59.csv'), # 7
           pd.read_csv('./simulation_results/2024-01-28_03-29-56.csv'), # 8
           pd.read_csv('./simulation_results/2024-01-28_13-38-03.csv'), # 9
           pd.read_csv('./simulation_results/2024-01-28_22-37-03.csv'), # 10
           pd.read_csv('./simulation_results/2024-01-29_08-53-56.csv'), # 11
           pd.read_csv('./simulation_results/2024-01-29_19-20-44.csv'), # 12
           pd.read_csv('./simulation_results/2024-01-30_05-35-24.csv'), # 13
           pd.read_csv('./simulation_results/2024-01-30_16-11-37.csv'), # 14
           pd.read_csv('./simulation_results/2024-01-31_03-32-21.csv'), # 15
           pd.read_csv('./simulation_results/2024-01-31_15-01-32.csv'), # 16
           pd.read_csv('./simulation_results/2024-02-01_02-38-14.csv'), # 17
           pd.read_csv('./simulation_results/2024-02-01_14-16-41.csv'), # 18
           pd.read_csv('./simulation_results/2024-02-02_01-53-34.csv'), # 19
           pd.read_csv('./simulation_results/2024-02-02_13-11-36.csv'), # 20
           pd.read_csv('./simulation_results/2024-02-03_00-45-57.csv'), # 21
           pd.read_csv('./simulation_results/2024-02-03_12-03-51.csv'), # 22
           pd.read_csv('./simulation_results/2024-02-03_23-21-15.csv'), # 23
           pd.read_csv('./simulation_results/2024-02-04_10-38-15.csv'), # 24
           pd.read_csv('./simulation_results/2024-02-04_22-27-16.csv'), # 25
           pd.read_csv('./simulation_results/2024-02-05_09-51-32.csv'), # 26
           pd.read_csv('./simulation_results/2024-02-05_21-09-34.csv'), # 27
           pd.read_csv('./simulation_results/2024-02-06_08-30-16.csv'), # 28
           pd.read_csv('./simulation_results/2024-02-06_19-58-25.csv'), # 29
          ]).assign(model='DyGrEncoder')
# Out:
#                     dataset    method  mrate mtype  lags  nof_filters  \
# 0  windmillsmallDyGrEncoder     STGCN    0.5  rand     8           12
# 1  windmillsmallDyGrEncoder  IT-STGCN    0.5  rand     8           12
# 0  windmillsmallDyGrEncoder     STGCN    0.5  rand     8           12
# 1  windmillsmallDyGrEncoder  IT-STGCN    0.5  rand     8           12
# 0  windmillsmallDyGrEncoder     STGCN    0.5  rand     8           12
# 1  windmillsmallDyGrEncoder  IT-STGCN    0.5  rand     8           12
# 0  windmillsmallDyGrEncoder     STGCN    0.5  rand     8           12
# 1  windmillsmallDyGrEncoder  IT-STGCN    0.5  rand     8           12
# 0  windmillsmallDyGrEncoder     STGCN    0.5  rand     8           12
# 1  windmillsmallDyGrEncoder  IT-STGCN    0.5  rand     8           12
# 0  windmillsmallDyGrEncoder     STGCN    0.5  rand     8           12
# 1  windmillsmallDyGrEncoder  IT-STGCN    0.5  rand     8           12
# 0  windmillsmallDyGrEncoder     STGCN    0.5  rand     8           12
# 1  windmillsmallDyGrEncoder  IT-STGCN    0.5  rand     8           12
# 0  windmillsmallDyGrEncoder     STGCN    0.5  rand     8           12
# 1  windmillsmallDyGrEncoder  IT-STGCN    0.5  rand     8           12
# 0  windmillsmallDyGrEncoder     STGCN    0.5  rand     8           12
# 1  windmillsmallDyGrEncoder  IT-STGCN    0.5  rand     8           12
# 0  windmillsmallDyGrEncoder     STGCN    0.5  rand     8           12
# 1  windmillsmallDyGrEncoder  IT-STGCN    0.5  rand     8           12
# 0  windmillsmallDyGrEncoder     STGCN    0.5  rand     8           12
# 1  windmillsmallDyGrEncoder  IT-STGCN    0.5  rand     8           12
# 0  windmillsmallDyGrEncoder     STGCN    0.5  rand     8           12
# 1  windmillsmallDyGrEncoder  IT-STGCN    0.5  rand     8           12
# 0  windmillsmallDyGrEncoder     STGCN    0.5  rand     8           12
# 1  windmillsmallDyGrEncoder  IT-STGCN    0.5  rand     8           12
# 0  windmillsmallDyGrEncoder     STGCN    0.5  rand     8           12
# 1  windmillsmallDyGrEncoder  IT-STGCN    0.5  rand     8           12
# 0  windmillsmallDyGrEncoder     STGCN    0.5  rand     8           12
# 1  windmillsmallDyGrEncoder  IT-STGCN    0.5  rand     8           12
# 0  windmillsmallDyGrEncoder     STGCN    0.5  rand     8           12
# 1  windmillsmallDyGrEncoder  IT-STGCN    0.5  rand     8           12
# 0  windmillsmallDyGrEncoder     STGCN    0.5  rand     8           12
# 1  windmillsmallDyGrEncoder  IT-STGCN    0.5  rand     8           12
# 0  windmillsmallDyGrEncoder     STGCN    0.5  rand     8           12
# 1  windmillsmallDyGrEncoder  IT-STGCN    0.5  rand     8           12
# 0  windmillsmallDyGrEncoder     STGCN    0.5  rand     8           12
# 1  windmillsmallDyGrEncoder  IT-STGCN    0.5  rand     8           12
# 0  windmillsmallDyGrEncoder     STGCN    0.5  rand     8           12
# 1  windmillsmallDyGrEncoder  IT-STGCN    0.5  rand     8           12
# 0  windmillsmallDyGrEncoder     STGCN    0.5  rand     8           12
# 1  windmillsmallDyGrEncoder  IT-STGCN    0.5  rand     8           12
# 0  windmillsmallDyGrEncoder     STGCN    0.5  rand     8           12
# 1  windmillsmallDyGrEncoder  IT-STGCN    0.5  rand     8           12
# 0  windmillsmallDyGrEncoder     STGCN    0.5  rand     8           12
# 1  windmillsmallDyGrEncoder  IT-STGCN    0.5  rand     8           12
# 0  windmillsmallDyGrEncoder     STGCN    0.5  rand     8           12
# 1  windmillsmallDyGrEncoder  IT-STGCN    0.5  rand     8           12
# 0  windmillsmallDyGrEncoder     STGCN    0.5  rand     8           12
# 1  windmillsmallDyGrEncoder  IT-STGCN    0.5  rand     8           12
# 0  windmillsmallDyGrEncoder     STGCN    0.5  rand     8           12
# 1  windmillsmallDyGrEncoder  IT-STGCN    0.5  rand     8           12
# 0  windmillsmallDyGrEncoder     STGCN    0.5  rand     8           12
# 1  windmillsmallDyGrEncoder  IT-STGCN    0.5  rand     8           12
# 0  windmillsmallDyGrEncoder     STGCN    0.5  rand     8           12
# 1  windmillsmallDyGrEncoder  IT-STGCN    0.5  rand     8           12
# 0  windmillsmallDyGrEncoder     STGCN    0.5  rand     8           12
# 1  windmillsmallDyGrEncoder  IT-STGCN    0.5  rand     8           12
#
#   inter_method  epoch       mse  calculation_time        model
# 0       linear     50  1.399403       1287.129029  DyGrEncoder
# 1       linear     50  0.995185      29379.109457  DyGrEncoder
# 0       linear     50  1.364160       2173.189621  DyGrEncoder
# 1       linear     50  0.990419      28916.702413  DyGrEncoder
# 0       linear     50  1.389555       2051.929635  DyGrEncoder
# 1       linear     50  0.995240      29975.615015  DyGrEncoder
# 0       linear     50  1.357190       2952.702301  DyGrEncoder
# 1       linear     50  0.990371      35552.520746  DyGrEncoder
# 0       linear     50  1.357729       1792.262343  DyGrEncoder
# 1       linear     50  0.995582      29117.568311  DyGrEncoder
# 0       linear     50  1.359898       2105.582545  DyGrEncoder
# 1       linear     50  0.995981      29467.090409  DyGrEncoder
# 0       linear     50  1.368710       2130.964975  DyGrEncoder
# 1       linear     50  0.991051      36747.895950  DyGrEncoder
# 0       linear     50  1.334106       2933.313962  DyGrEncoder
# 1       linear     50  0.998642      36430.339930  DyGrEncoder
# 0       linear     50  1.412649       2965.455756  DyGrEncoder
# 1       linear     50  0.999837      33455.468574  DyGrEncoder
# 0       linear     50  1.441853       2218.268918  DyGrEncoder
# 1       linear     50  0.993613      30066.995713  DyGrEncoder
# 0       linear     50  1.399500       2432.715765  DyGrEncoder
# 1       linear     50  0.990537      34457.809057  DyGrEncoder
# 0       linear     50  1.399625       2766.714232  DyGrEncoder
# 1       linear     50  0.998935      34741.399217  DyGrEncoder
# 0       linear     50  1.359628       2726.620480  DyGrEncoder
# 1       linear     50  0.995822      34107.222316  DyGrEncoder
# 0       linear     50  1.364663       2469.192380  DyGrEncoder
# 1       linear     50  0.997140      35630.297760  DyGrEncoder
# 0       linear     50  1.329520       3467.050085  DyGrEncoder
# 1       linear     50  0.993710      37272.261736  DyGrEncoder
# 0       linear     50  1.354636       3480.395607  DyGrEncoder
# 1       linear     50  0.996525      37777.825738  DyGrEncoder
# 0       linear     50  1.359832       2408.820995  DyGrEncoder
# 1       linear     50  0.994101      39275.355947  DyGrEncoder
# 0       linear     50  1.367778       3060.937909  DyGrEncoder
# 1       linear     50  1.000241      38787.345441  DyGrEncoder
# 0       linear     50  1.381336       3364.477480  DyGrEncoder
# 1       linear     50  0.994113      38351.691845  DyGrEncoder
# 0       linear     50  1.377518       3119.150923  DyGrEncoder
# 1       linear     50  0.999564      37523.436377  DyGrEncoder
# 0       linear     50  1.373124       2906.893905  DyGrEncoder
# 1       linear     50  0.997918      38664.995572  DyGrEncoder
# 0       linear     50  1.372201       2434.499733  DyGrEncoder
# 1       linear     50  0.993323      38164.006072  DyGrEncoder
# 0       linear     50  1.357271       2472.156974  DyGrEncoder
# 1       linear     50  0.992295      38109.219269  DyGrEncoder
# 0       linear     50  1.357042       3157.539882  DyGrEncoder
# 1       linear     50  0.992840      37329.231196  DyGrEncoder
# 0       linear     50  1.408575       3458.981094  DyGrEncoder
# 1       linear     50  0.999269      39040.442227  DyGrEncoder
# 0       linear     50  1.371240       2984.791893  DyGrEncoder
# 1       linear     50  0.997022      37984.938489  DyGrEncoder
# 0       linear     50  1.386848       3035.623034  DyGrEncoder
# 1       linear     50  0.997089      37557.215438  DyGrEncoder
# 0       linear     50  1.355586       3515.655090  DyGrEncoder
# 1       linear     50  0.996702      37227.563563  DyGrEncoder
# 0       linear     50  1.363391       3503.772657  DyGrEncoder
# 1       linear     50  0.997920      37693.790984  DyGrEncoder

# %% [markdown]
# LRGCN

# %%
pd.concat([pd.read_csv('./simulation_results/2024-01-25_00-26-15.csv'), # 1
           pd.read_csv('./simulation_results/2024-01-25_10-04-35.csv'), # 2
           pd.read_csv('./simulation_results/2024-01-25_19-42-50.csv'), # 3
           pd.read_csv('./simulation_results/2024-01-26_06-17-49.csv'), # 4
           pd.read_csv('./simulation_results/2024-01-26_16-19-15.csv'), # 5
           pd.read_csv('./simulation_results/2024-01-27_01-56-42.csv'), # 6
           pd.read_csv('./simulation_results/2024-01-27_12-31-42.csv'), # 7
           pd.read_csv('./simulation_results/2024-01-27_23-41-30.csv'), # 8
           pd.read_csv('./simulation_results/2024-01-28_10-50-18.csv'), # 9
           pd.read_csv('./simulation_results/2024-01-28_20-31-17.csv'), # 10
           pd.read_csv('./simulation_results/2024-01-29_07-11-35.csv'), # 11
           pd.read_csv('./simulation_results/2024-01-29_18-05-25.csv'), # 12
           pd.read_csv('./simulation_results/2024-01-30_04-49-08.csv'), # 13
           pd.read_csv('./simulation_results/2024-01-30_20-31-22.csv'), # 14
           pd.read_csv('./simulation_results/2024-01-31_08-00-27.csv'), # 15
           pd.read_csv('./simulation_results/2024-01-31_19-44-35.csv'), # 16
           pd.read_csv('./simulation_results/2024-02-01_07-39-17.csv'), # 17
           pd.read_csv('./simulation_results/2024-02-01_19-37-34.csv'), # 18
           pd.read_csv('./simulation_results/2024-02-02_06-52-35.csv'), # 19
           pd.read_csv('./simulation_results/2024-02-02_18-45-51.csv'), # 20
           pd.read_csv('./simulation_results/2024-02-03_06-20-39.csv'), # 21
           pd.read_csv('./simulation_results/2024-02-03_17-55-52.csv'), # 22
           pd.read_csv('./simulation_results/2024-02-04_05-24-54.csv'), # 23
           pd.read_csv('./simulation_results/2024-02-04_16-55-08.csv'), # 24
           pd.read_csv('./simulation_results/2024-02-05_04-24-45.csv'), # 25
           pd.read_csv('./simulation_results/2024-02-05_16-07-40.csv'), # 26
           pd.read_csv('./simulation_results/2024-02-06_03-30-29.csv'), # 27
           pd.read_csv('./simulation_results/2024-02-06_15-15-44.csv'), # 28
           pd.read_csv('./simulation_results/2024-02-07_01-39-04.csv'), # 29
          ]).assign(model='LRGCN')
# Out:
#               dataset    method  mrate mtype  lags  nof_filters inter_method  \
# 0  windmillsmallLRGCN     STGCN    0.5  rand     8           12       linear
# 1  windmillsmallLRGCN  IT-STGCN    0.5  rand     8           12       linear
# 0  windmillsmallLRGCN     STGCN    0.5  rand     8           12       linear
# 1  windmillsmallLRGCN  IT-STGCN    0.5  rand     8           12       linear
# 0  windmillsmallLRGCN     STGCN    0.5  rand     8           12       linear
# 1  windmillsmallLRGCN  IT-STGCN    0.5  rand     8           12       linear
# 0  windmillsmallLRGCN     STGCN    0.5  rand     8           12       linear
# 1  windmillsmallLRGCN  IT-STGCN    0.5  rand     8           12       linear
# 0  windmillsmallLRGCN     STGCN    0.5  rand     8           12       linear
# 1  windmillsmallLRGCN  IT-STGCN    0.5  rand     8           12       linear
# 0  windmillsmallLRGCN     STGCN    0.5  rand     8           12       linear
# 1  windmillsmallLRGCN  IT-STGCN    0.5  rand     8           12       linear
# 0  windmillsmallLRGCN     STGCN    0.5  rand     8           12       linear
# 1  windmillsmallLRGCN  IT-STGCN    0.5  rand     8           12       linear
# 0  windmillsmallLRGCN     STGCN    0.5  rand     8           12       linear
# 1  windmillsmallLRGCN  IT-STGCN    0.5  rand     8           12       linear
# 0  windmillsmallLRGCN     STGCN    0.5  rand     8           12       linear
# 1  windmillsmallLRGCN  IT-STGCN    0.5  rand     8           12       linear
# 0  windmillsmallLRGCN     STGCN    0.5  rand     8           12       linear
# 1  windmillsmallLRGCN  IT-STGCN    0.5  rand     8           12       linear
# 0  windmillsmallLRGCN     STGCN    0.5  rand     8           12       linear
# 1  windmillsmallLRGCN  IT-STGCN    0.5  rand     8           12       linear
# 0  windmillsmallLRGCN     STGCN    0.5  rand     8           12       linear
# 1  windmillsmallLRGCN  IT-STGCN    0.5  rand     8           12       linear
# 0  windmillsmallLRGCN     STGCN    0.5  rand     8           12       linear
# 1  windmillsmallLRGCN  IT-STGCN    0.5  rand     8           12       linear
# 0  windmillsmallLRGCN     STGCN    0.5  rand     8           12       linear
# 1  windmillsmallLRGCN  IT-STGCN    0.5  rand     8           12       linear
# 0  windmillsmallLRGCN     STGCN    0.5  rand     8           12       linear
# 1  windmillsmallLRGCN  IT-STGCN    0.5  rand     8           12       linear
# 0  windmillsmallLRGCN     STGCN    0.5  rand     8           12       linear
# 1  windmillsmallLRGCN  IT-STGCN    0.5  rand     8           12       linear
# 0  windmillsmallLRGCN     STGCN    0.5  rand     8           12       linear
# 1  windmillsmallLRGCN  IT-STGCN    0.5  rand     8           12       linear
# 0  windmillsmallLRGCN     STGCN    0.5  rand     8           12       linear
# 1  windmillsmallLRGCN  IT-STGCN    0.5  rand     8           12       linear
# 0  windmillsmallLRGCN     STGCN    0.5  rand     8           12       linear
# 1  windmillsmallLRGCN  IT-STGCN    0.5  rand     8           12       linear
# 0  windmillsmallLRGCN     STGCN    0.5  rand     8           12       linear
# 1  windmillsmallLRGCN  IT-STGCN    0.5  rand     8           12       linear
# 0  windmillsmallLRGCN     STGCN    0.5  rand     8           12       linear
# 1  windmillsmallLRGCN  IT-STGCN    0.5  rand     8           12       linear
# 0  windmillsmallLRGCN     STGCN    0.5  rand     8           12       linear
# 1  windmillsmallLRGCN  IT-STGCN    0.5  rand     8           12       linear
# 0  windmillsmallLRGCN     STGCN    0.5  rand     8           12       linear
# 1  windmillsmallLRGCN  IT-STGCN    0.5  rand     8           12       linear
# 0  windmillsmallLRGCN     STGCN    0.5  rand     8           12       linear
# 1  windmillsmallLRGCN  IT-STGCN    0.5  rand     8           12       linear
# 0  windmillsmallLRGCN     STGCN    0.5  rand     8           12       linear
# 1  windmillsmallLRGCN  IT-STGCN    0.5  rand     8           12       linear
# 0  windmillsmallLRGCN     STGCN    0.5  rand     8           12       linear
# 1  windmillsmallLRGCN  IT-STGCN    0.5  rand     8           12       linear
# 0  windmillsmallLRGCN     STGCN    0.5  rand     8           12       linear
# 1  windmillsmallLRGCN  IT-STGCN    0.5  rand     8           12       linear
# 0  windmillsmallLRGCN     STGCN    0.5  rand     8           12       linear
# 1  windmillsmallLRGCN  IT-STGCN    0.5  rand     8           12       linear
# 0  windmillsmallLRGCN     STGCN    0.5  rand     8           12       linear
# 1  windmillsmallLRGCN  IT-STGCN    0.5  rand     8           12       linear
#
#    epoch       mse  calculation_time  model
# 0     50  1.419365       2706.468822  LRGCN
# 1     50  0.992892      32066.538508  LRGCN
# 0     50  1.353130       3044.404266  LRGCN
# 1     50  0.992260      31543.776187  LRGCN
# 0     50  1.334008       3188.164355  LRGCN
# 1     50  0.995353      31375.653413  LRGCN
# 0     50  1.337325       3132.741006  LRGCN
# 1     50  0.992040      34839.083089  LRGCN
# 0     50  1.371451       3077.019833  LRGCN
# 1     50  0.993275      32914.471802  LRGCN
# 0     50  1.312752       2960.035801  LRGCN
# 1     50  0.991522      31567.534146  LRGCN
# 0     50  1.377256       3160.819826  LRGCN
# 1     50  0.995118      34827.182467  LRGCN
# 0     50  1.313329       3004.048005  LRGCN
# 1     50  0.994629      37079.614291  LRGCN
# 0     50  1.383590       3104.627234  LRGCN
# 1     50  0.995887      36924.668494  LRGCN
# 0     50  1.365137       3024.064458  LRGCN
# 1     50  0.997074      31705.173305  LRGCN
# 0     50  1.276580       3086.325403  LRGCN
# 1     50  0.996068      35222.951252  LRGCN
# 0     50  1.286076       3006.959019  LRGCN
# 1     50  0.999566      36135.009540  LRGCN
# 0     50  1.343256       3036.854056  LRGCN
# 1     50  0.994399      35492.232673  LRGCN
# 0     50  1.327112       2777.947501  LRGCN
# 1     50  0.995238      38852.632940  LRGCN
# 0     50  1.375718       3376.041894  LRGCN
# 1     50  0.993775      37835.691170  LRGCN
# 0     50  1.393392       3340.517964  LRGCN
# 1     50  0.991958      38822.624055  LRGCN
# 0     50  1.330508       3339.108742  LRGCN
# 1     50  0.996617      39423.872617  LRGCN
# 0     50  1.366228       3332.602750  LRGCN
# 1     50  0.997364      39630.877299  LRGCN
# 0     50  1.410906       3002.027545  LRGCN
# 1     50  0.995744      37379.095729  LRGCN
# 0     50  1.251453       3224.766735  LRGCN
# 1     50  0.992620      39462.753875  LRGCN
# 0     50  1.386282       3402.282424  LRGCN
# 1     50  0.994949      38137.763252  LRGCN
# 0     50  1.336976       3369.900418  LRGCN
# 1     50  0.996776      38200.478390  LRGCN
# 0     50  1.354056       3327.494386  LRGCN
# 1     50  0.997171      37916.115074  LRGCN
# 0     50  1.335847       3094.157737  LRGCN
# 1     50  0.994726      38183.117586  LRGCN
# 0     50  1.303159       3440.489176  LRGCN
# 1     50  0.994934      37793.148385  LRGCN
# 0     50  1.371021       3347.464527  LRGCN
# 1     50  0.995092      38695.340040  LRGCN
# 0     50  1.368175       3344.821873  LRGCN
# 1     50  0.993154      37509.780239  LRGCN
# 0     50  1.390804       2993.378181  LRGCN
# 1     50  0.992177      39213.223529  LRGCN
# 0     50  1.317134       3371.466012  LRGCN
# 1     50  0.992329      33923.958436  LRGCN

# %%
pd.concat([pd.read_csv('./simulation_results/2024-02-07_11-03-03.csv'), # 1
           pd.read_csv('./simulation_results/2024-02-07_20-27-31.csv'), # 2
           pd.read_csv('./simulation_results/2024-02-08_05-56-58.csv'), # 3
          ]).assign(model='LRGCN')
# Out:
#               dataset    method  mrate mtype  lags  nof_filters inter_method  \
# 0  windmillsmallLRGCN     STGCN    0.8  rand     8           12       linear
# 1  windmillsmallLRGCN  IT-STGCN    0.8  rand     8           12       linear
# 0  windmillsmallLRGCN     STGCN    0.8  rand     8           12       linear
# 1  windmillsmallLRGCN  IT-STGCN    0.8  rand     8           12       linear
# 0  windmillsmallLRGCN     STGCN    0.8  rand     8           12       linear
# 1  windmillsmallLRGCN  IT-STGCN    0.8  rand     8           12       linear
#
#    epoch       mse  calculation_time  model
# 0     50  1.345522       2939.966668  LRGCN
# 1     50  1.184878      30792.403946  LRGCN
# 0     50  1.313609       3103.724974  LRGCN
# 1     50  1.185731      30638.931736  LRGCN
# 0     50  1.265125       3161.842281  LRGCN
# 1     50  1.220967      30893.167516  LRGCN

# %% [markdown]
# ---

# %% [markdown]
# monte(linear)

# %% [markdown]
# block

# %%
# pd.concat([pd.read_csv('./simulation_results/2024-01-30_06-39-52.csv').assign(model='LRGCN'),
#            pd.read_csv('./simulation_results/monte_random.csv'),
#            pd.read_csv('./simulation_results/2024-01-26_05-21-17.csv').assign(model='GComvGRU'), # epoch 15(1)
#            pd.read_csv('./simulation_results/2024-01-26_09-48-48.csv').assign(model='GComvGRU'), # epoch 15(2)
#            pd.read_csv('./simulation_results/2024-01-27_17-54-13.csv').assign(model='GConvLSTM'), # epoch 30
#            pd.read_csv('./simulation_results/2024-01-27_23-03-18.csv').assign(model='GCLSTM'), # epoch 30
#            pd.read_csv('./simulation_results/2024-01-28_03-57-09.csv').assign(model='DyGrEncoder'), # epoch 30
#            pd.read_csv('./simulation_results/2024-01-28_10-28-48.csv').assign(model='DCRNN'), # epoch 30
#            pd.read_csv('./simulation_results/2024-01-29_00-25-33.csv').assign(model='LRGCN'), # epoch 30
#            pd.read_csv('./simulation_results/2024-01-29_03-54-40.csv').assign(model='EvolveGCNH'), # epoch 30
#            pd.read_csv('./simulation_results/2024-01-29_06-34-15.csv').assign(model='EvolveGCNO'), # epoch 30
#            pd.read_csv('./simulation_results/2024-01-29_12-04-23.csv').assign(model='TGCN'), # epoch 30
#           ]).iloc[:,1:].to_csv('./monte_linear.csv',index=False)

# %% [markdown]
# ---

# %% [markdown]
# pedalme

# %%
# pd.concat([pd.read_csv('./simulation_results/2024-02-01_12-21-45.csv').assign(model='GComvGRU'),
#            pd.read_csv('./simulation_results/2024-02-01_13-06-50.csv').assign(model='DyGrEncoder'),
#            pd.read_csv('./simulation_results/2024-02-01_13-25-34.csv').assign(model='EvolveGCNH'),
#            pd.read_csv('./simulation_results/2024-02-01_13-38-43.csv').assign(model='EvolveGCNO'),
#            pd.read_csv('./simulation_results/2024-02-01_14-02-20.csv').assign(model='TGCN'),
#            pd.read_csv('./simulation_results/2024-02-01_14-50-24.csv').assign(model='GConvLSTM'),
#            pd.read_csv('./simulation_results/2024-02-01_15-12-44.csv').assign(model='GCLSTM'),
#            pd.read_csv('./simulation_results/2024-02-01_16-07-18.csv').assign(model='LRGCN'),
#            pd.read_csv('./simulation_results/2024-02-01_16-27-28.csv').assign(model='DCRNN'),
#            pd.read_csv('./simulation_results/2024-02-01_16-37-48.csv').assign(model='GComvGRU'),
#            pd.read_csv('./simulation_results/2024-02-01_16-48-51.csv').assign(model='DyGrEncoder'),
#            pd.read_csv('./simulation_results/2024-02-01_16-53-04.csv').assign(model='EvolveGCNH'),
#            pd.read_csv('./simulation_results/2024-02-01_16-56-04.csv').assign(model='EvolveGCNO'),
#            pd.read_csv('./simulation_results/2024-02-01_17-01-04.csv').assign(model='TGCN'),
#            pd.read_csv('./simulation_results/2024-02-01_17-11-54.csv').assign(model='GConvLSTM'),
#            pd.read_csv('./simulation_results/2024-02-01_17-17-03.csv').assign(model='GCLSTM'),
#            pd.read_csv('./simulation_results/2024-02-01_17-23-48.csv').assign(model='LRGCN'),
#            pd.read_csv('./simulation_results/2024-02-01_17-27-22.csv').assign(model='DCRNN'),
#           ]).iloc[:,1:].to_csv('./pedalme_linear.csv',index=False)
